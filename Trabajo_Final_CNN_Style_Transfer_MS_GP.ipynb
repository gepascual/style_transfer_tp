# %% [markdown]
# # Style Transfer
#
# <img src="https://i0.wp.com/chelseatroy.com/wp-content/uploads/2018/12/neural_style_transfer.png?resize=768%2C311&ssl=1">
#
# La idea de este trabajo final es reproducir el siguiente paper:
#
# https://arxiv.org/pdf/1508.06576.pdf
#
# El objetivo es transferir el estilo de una imagen dada a otra imagen distinta.
#
# Como hemos visto en clase, las primeras capas de una red convolucional se activan ante la presencia de ciertos patrones vinculados a detalles muy pequeños.
#
# A medida que avanzamos en las distintas capas de una red neuronal convolucional, los filtros se van activando a medida que detectan patrones de formas cada vez mas complejos.
#
# Lo que propone este paper es asignarle a la activación de las primeras capas de una red neuronal convolucional (por ejemplo VGG19) la definición del estilo y a la activación de las últimas capas de la red neuronal convolucional, la definición del contenido.
#
# La idea de este paper es, a partir de dos imágenes (una que aporte el estilo y otra que aporte el contenido) analizar cómo es la activación de las primeras capas para la imagen que aporta el estilo y cómo es la activación de las últimas capas de la red convolucional para la imagen que aporta el contenido. A partir de esto se intentará sintetizar una imagen que active los filtros de las primeras capas que se activaron con la imagen que aporta el estilo y los filtros de las últimas capas que se activaron con la imagen que aporta el contenido.
#
# A este procedimiento se lo denomina neural style transfer.
#
# # En este trabajo se deberá leer el paper mencionado y en base a ello, entender la implementación que se muestra a continuación y contestar preguntas sobre la misma.
#
# # Una metodología posible es hacer una lectura rápida del paper (aunque esto signifique no entender algunos detalles del mismo) y luego ir analizando el código y respondiendo las preguntas. A medida que se planteen las preguntas, volviendo a leer secciones específicas del paper terminará de entender los detalles que pudieran haber quedado pendientes.
#
# Lo primero que haremos es cargar dos imágenes, una que aporte el estilo y otra que aporte el contenido. A tal fin utilizaremos imágenes disponibles en la web.

# %%
# Imagen para estilo
# !wget https://upload.wikimedia.org/wikipedia/commons/5/52/La_noche_estrellada1.jpg

# Imagen para contenido
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Neckarfront_T%C3%BCbingen_Mai_2017.jpg/775px-Neckarfront_T%C3%BCbingen_Mai_2017.jpg

# Creamos el directorio para los archivos de salida
# !mkdir /content/output
# Out:
# --2020-03-24 19:31:19--  https://upload.wikimedia.org/wikipedia/commons/5/52/La_noche_estrellada1.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 103.102.166.240, 2001:df2:e500:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|103.102.166.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 223725 (218K) [image/jpeg]
# Saving to: ‘La_noche_estrellada1.jpg’
#
# La_noche_estrellada 100%[===================>] 218.48K  1000KB/s    in 0.2s
#
# 2020-03-24 19:31:20 (1000 KB/s) - ‘La_noche_estrellada1.jpg’ saved [223725/223725]
#
# --2020-03-24 19:31:24--  https://upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Neckarfront_T%C3%BCbingen_Mai_2017.jpg/775px-Neckarfront_T%C3%BCbingen_Mai_2017.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 103.102.166.240, 2001:df2:e500:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|103.102.166.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 153015 (149K) [image/jpeg]
# Saving to: ‘775px-Neckarfront_Tübingen_Mai_2017.jpg’
#
# 775px-Neckarfront_T 100%[===================>] 149.43K   365KB/s    in 0.4s
#
# 2020-03-24 19:31:25 (365 KB/s) - ‘775px-Neckarfront_Tübingen_Mai_2017.jpg’ saved [153015/153015]

# %%
from keras.preprocessing.image import load_img, save_img, img_to_array
import numpy as np
from scipy.optimize import fmin_l_bfgs_b
import time
import argparse

from keras.applications import vgg19
from keras import backend as K
from pathlib import Path

# %%
# Definimos las imagenes que vamos a utilizar, y el directorio de salida

base_image_path = Path("/content/775px-Neckarfront_Tübingen_Mai_2017.jpg")
style_reference_image_path = Path("/content/La_noche_estrellada1.jpg")
result_prefix = Path("/content/output")
iterations = 100

# %% [markdown]
# # 1) En base a lo visto en el paper ¿Qué significan los parámetros definidos en la siguiente celda?
#
# Respuesta: Son los pesos de los diferentes componentes de la loss. Permiten controlar el impacto tanto del content como del estilo en la loss total. Total_variation_weihght es el peso que controla el 'nivel de ruido' en la imagen generada, corresponde al término de regularización de la loss (total variation loss)

# %%
total_variation_weight = 0.1
style_weight = 3
content_weight = 10

# %%
# Definimos el tamaño de las imágenes a utilizar
width, height = load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)

# %% [markdown]
# # 2) Explicar qué hace la siguiente celda. En especial las últimas dos líneas de la función antes del return. ¿Por qué?
#
# Ayuda: https://keras.io/applications/
#
# Respuesta: define una funcion para preprocesar la imagen, abre la imagen, la convierte en un array, luego expande el shape del array y lo convierte en un tensor para ser procesado por VGG19

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %% [markdown]
# # 3) Habiendo comprendido lo que hace la celda anterior, explique de manera muy concisa qué hace la siguiente celda. ¿Qué relación tiene con la celda anterior?
#
# Respuesta: Convierte un tensor en una imagen. Es lo inverso a la celda anterior.

# %%
def deprocess_image(x):
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
# get tensor representations of our images
# K.variable convierte un numpy array en un tensor, para 
base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_reference_image_path))

# %%
combination_image = K.placeholder((1, img_nrows, img_ncols, 3))

# %% [markdown]
# Aclaración:
#
# La siguiente celda sirve para procesar las tres imagenes (contenido, estilo y salida) en un solo batch.

# %%
# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image], axis=0)

# %%
# build the VGG19 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')

# get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Out:
# Model loaded.

# %% [markdown]
# # 4) En la siguientes celdas:
#
# - ¿Qué es la matriz de Gram?¿Para qué se usa?
# La matriz de Gram da las correlaciones entre los features. Es el producto punto entre los vectores de activación.  Los features extraídos de la red convolucional contienen información de contenido (estrtuctura y ubicación), esa información puede eliminarse aplicando la matriz de Gram a esos features. Permitiendo separar estilo de contenido.
#
# - ¿Por qué se permutan las dimensiones de x?
# Por definición la matriz de Gram es el producto punto del feature map por su transpuesta en una capa.

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %% [markdown]
# # 5) Losses:
#
# Explicar qué mide cada una de las losses en las siguientes tres celdas.
#
# Rta:
# "style loss" distancia entre el estilo de la imagen de referencia y el de la imagen generada.
#
# - For the style loss, we first define something called a Gram matrix. The terms of this matrix are proportional to the covariances of corresponding sets of features, and thus captures information about which features tend to activate together. By only capturing these aggregate statistics across the image, they are blind to the specific arrangement of objects inside the image. This is what allows them to capture information about style independent of content. **The style loss is then the (scaled, squared) Frobenius norm of the difference between the Gram matrices of the style and combination images.**
#
# "content loss" distancia entre el contenido de las imagenes de referencia y la generada
#
# - **The content loss is the (scaled, squared) Euclidean distance between feature representations of the content and combination images.**
#
# "total variation loss" regularización, permite mantener la imagen generada 'coherente' - intenta minimizar las diferencias entre la imagen de contenido, la de estilo y la imagen generada
#
# -If you were to solve the optimisation problem with only the two loss terms we've introduced so far (style and content), you'll find that the output is quite noisy. We thus add another term, called **the total variation loss (a regularisation term) that encourages spatial smoothness.**
#
# http://www.sai-tai.com/blog/transfer-learning-lstm/
# https://towardsdatascience.com/light-on-math-machine-learning-intuitive-guide-to-neural-style-transfer-ef88e46697ee

# %%
def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def total_variation_loss(x):
    assert K.ndim(x) == 4
    a = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
    b = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
# Armamos la loss total
loss = K.variable(0.0)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(base_image_features,
                                            combination_features)

feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :] 
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss = loss + (style_weight / len(feature_layers)) * sl
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
grads = K.gradients(loss, combination_image)

outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs += grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image], outputs)

# %% [markdown]
# # 6) Explique el propósito de las siguientes tres celdas. ¿Qué hace la función fmin_l_bfgs_b? ¿En qué se diferencia con la implementación del paper? ¿Se puede utilizar alguna alternativa?
#
# Respuesta:
#
# Como indica el comentario en la clase Evaluator:
# Se define una clase Evaluator que calcula la loss y los gradientes en un paso, y los devuelve en dos funciones separadas loss y grads. Se hace de esta manera porque scipy.optimize requiere funciones separadas para loss y gradientes pero calcularlos por separado es ineficiente.
#
# De acuerdo a la documentación, la función fmin_l_bfgs_b minimiza una función (en este caso recive evaluator.loss) usando el algoritmo L-BFGS **'a quasi-Newton algorithm that's significantly quicker to converge than standard gradient descent'**. En el paper de  Leon A. Gatys, se utiliza el algoritmo L-BFGS.
#
# Una alternativa sería utilizar Adam (https://blog.slavv.com/picking-an-optimizer-for-style-transfer-86e7b8cba84b)
#
# http://ai.stanford.edu/~acoates/papers/LeNgiCoaLahProNg11.pdf

# %%
def eval_loss_and_grads(x):
    x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.

# %%
class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

# %% [markdown]
# # 7) Ejecute la siguiente celda y observe las imágenes de salida en cada iteración.

# %%
evaluator = Evaluator()

# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())
    fname = result_prefix / ('output_at_iteration_%d.png' % i)
    save_img(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 5936227000.0
# Image saved as /content/output3/output_at_iteration_0.png
# Iteration 0 completed in 5s
# Start of iteration 1
# Current loss value: 4033651000.0
# Image saved as /content/output3/output_at_iteration_1.png
# Iteration 1 completed in 4s
# Start of iteration 2
# Current loss value: 3358417700.0
# Image saved as /content/output3/output_at_iteration_2.png
# Iteration 2 completed in 4s
# Start of iteration 3
# Current loss value: 2996365000.0
# Image saved as /content/output3/output_at_iteration_3.png
# Iteration 3 completed in 4s
# Start of iteration 4
# Current loss value: 2767132200.0
# Image saved as /content/output3/output_at_iteration_4.png
# Iteration 4 completed in 4s
# Start of iteration 5
# Current loss value: 2604612400.0
# Image saved as /content/output3/output_at_iteration_5.png
# Iteration 5 completed in 4s
# Start of iteration 6
# Current loss value: 2471566800.0
# Image saved as /content/output3/output_at_iteration_6.png
# Iteration 6 completed in 4s
# Start of iteration 7
# Current loss value: 2371286500.0
# Image saved as /content/output3/output_at_iteration_7.png
# Iteration 7 completed in 4s
# Start of iteration 8
# Current loss value: 2295391500.0
# Image saved as /content/output3/output_at_iteration_8.png
# Iteration 8 completed in 4s
# Start of iteration 9
# Current loss value: 2226464500.0
# Image saved as /content/output3/output_at_iteration_9.png
# Iteration 9 completed in 4s
# Start of iteration 10
# Current loss value: 2166658000.0
# Image saved as /content/output3/output_at_iteration_10.png
# Iteration 10 completed in 4s
# Start of iteration 11
# Current loss value: 2116226700.0
# Image saved as /content/output3/output_at_iteration_11.png
# Iteration 11 completed in 4s
# Start of iteration 12
# Current loss value: 2071243300.0
# Image saved as /content/output3/output_at_iteration_12.png
# Iteration 12 completed in 4s
# Start of iteration 13
# Current loss value: 2032362200.0
# Image saved as /content/output3/output_at_iteration_13.png
# Iteration 13 completed in 4s
# Start of iteration 14
# Current loss value: 1997141000.0
# Image saved as /content/output3/output_at_iteration_14.png
# Iteration 14 completed in 4s
# Start of iteration 15
# Current loss value: 1965761200.0
# Image saved as /content/output3/output_at_iteration_15.png
# Iteration 15 completed in 4s
# Start of iteration 16
# Current loss value: 1936798100.0
# Image saved as /content/output3/output_at_iteration_16.png
# Iteration 16 completed in 4s
# Start of iteration 17
# Current loss value: 1911033700.0
# Image saved as /content/output3/output_at_iteration_17.png
# Iteration 17 completed in 4s
# Start of iteration 18
# Current loss value: 1886395400.0
# Image saved as /content/output3/output_at_iteration_18.png
# Iteration 18 completed in 4s
# Start of iteration 19
# Current loss value: 1864438000.0
# Image saved as /content/output3/output_at_iteration_19.png
# Iteration 19 completed in 4s
# Start of iteration 20
# Current loss value: 1843861800.0
# Image saved as /content/output3/output_at_iteration_20.png
# Iteration 20 completed in 4s
# Start of iteration 21
# Current loss value: 1824743400.0
# Image saved as /content/output3/output_at_iteration_21.png
# Iteration 21 completed in 4s
# Start of iteration 22
# Current loss value: 1806821200.0
# Image saved as /content/output3/output_at_iteration_22.png
# Iteration 22 completed in 4s
# Start of iteration 23
# Current loss value: 1790675600.0
# Image saved as /content/output3/output_at_iteration_23.png
# Iteration 23 completed in 4s
# Start of iteration 24
# Current loss value: 1775726500.0
# Image saved as /content/output3/output_at_iteration_24.png
# Iteration 24 completed in 4s
# Start of iteration 25
# Current loss value: 1761533300.0
# Image saved as /content/output3/output_at_iteration_25.png
# Iteration 25 completed in 4s
# Start of iteration 26
# Current loss value: 1747951700.0
# Image saved as /content/output3/output_at_iteration_26.png
# Iteration 26 completed in 4s
# Start of iteration 27
# Current loss value: 1735182000.0
# Image saved as /content/output3/output_at_iteration_27.png
# Iteration 27 completed in 4s
# Start of iteration 28
# Current loss value: 1723078700.0
# Image saved as /content/output3/output_at_iteration_28.png
# Iteration 28 completed in 4s
# Start of iteration 29
# Current loss value: 1711826200.0
# Image saved as /content/output3/output_at_iteration_29.png
# Iteration 29 completed in 4s
# Start of iteration 30
# Current loss value: 1701520600.0
# Image saved as /content/output3/output_at_iteration_30.png
# Iteration 30 completed in 4s
# Start of iteration 31
# Current loss value: 1691774000.0
# Image saved as /content/output3/output_at_iteration_31.png
# Iteration 31 completed in 4s
# Start of iteration 32
# Current loss value: 1682753400.0
# Image saved as /content/output3/output_at_iteration_32.png
# Iteration 32 completed in 4s
# Start of iteration 33
# Current loss value: 1674638600.0
# Image saved as /content/output3/output_at_iteration_33.png
# Iteration 33 completed in 4s
# Start of iteration 34
# Current loss value: 1666738200.0
# Image saved as /content/output3/output_at_iteration_34.png
# Iteration 34 completed in 4s
# Start of iteration 35
# Current loss value: 1659454500.0
# Image saved as /content/output3/output_at_iteration_35.png
# Iteration 35 completed in 4s
# Start of iteration 36
# Current loss value: 1652456000.0
# Image saved as /content/output3/output_at_iteration_36.png
# Iteration 36 completed in 4s
# Start of iteration 37
# Current loss value: 1646006100.0
# Image saved as /content/output3/output_at_iteration_37.png
# Iteration 37 completed in 4s
# Start of iteration 38
# Current loss value: 1639603700.0
# Image saved as /content/output3/output_at_iteration_38.png
# Iteration 38 completed in 4s
# Start of iteration 39
# Current loss value: 1633864100.0
# Image saved as /content/output3/output_at_iteration_39.png
# Iteration 39 completed in 4s
# Start of iteration 40
# Current loss value: 1628431900.0
# Image saved as /content/output3/output_at_iteration_40.png
# Iteration 40 completed in 4s
# Start of iteration 41
# Current loss value: 1623277300.0
# Image saved as /content/output3/output_at_iteration_41.png
# Iteration 41 completed in 4s
# Start of iteration 42
# Current loss value: 1618394800.0
# Image saved as /content/output3/output_at_iteration_42.png
# Iteration 42 completed in 4s
# Start of iteration 43
# Current loss value: 1613847700.0
# Image saved as /content/output3/output_at_iteration_43.png
# Iteration 43 completed in 4s
# Start of iteration 44
# Current loss value: 1609363700.0
# Image saved as /content/output3/output_at_iteration_44.png
# Iteration 44 completed in 4s
# Start of iteration 45
# Current loss value: 1605132900.0
# Image saved as /content/output3/output_at_iteration_45.png
# Iteration 45 completed in 4s
# Start of iteration 46
# Current loss value: 1601109800.0
# Image saved as /content/output3/output_at_iteration_46.png
# Iteration 46 completed in 4s
# Start of iteration 47
# Current loss value: 1597166700.0
# Image saved as /content/output3/output_at_iteration_47.png
# Iteration 47 completed in 4s
# Start of iteration 48
# Current loss value: 1593469200.0
# Image saved as /content/output3/output_at_iteration_48.png
# Iteration 48 completed in 4s
# Start of iteration 49
# Current loss value: 1589729200.0
# Image saved as /content/output3/output_at_iteration_49.png
# Iteration 49 completed in 4s
# Start of iteration 50
# Current loss value: 1586199400.0
# Image saved as /content/output3/output_at_iteration_50.png
# Iteration 50 completed in 4s
# Start of iteration 51
# Current loss value: 1582709200.0
# Image saved as /content/output3/output_at_iteration_51.png
# Iteration 51 completed in 4s
# Start of iteration 52
# Current loss value: 1579496000.0
# Image saved as /content/output3/output_at_iteration_52.png
# Iteration 52 completed in 4s
# Start of iteration 53
# Current loss value: 1576386200.0
# Image saved as /content/output3/output_at_iteration_53.png
# Iteration 53 completed in 4s
# Start of iteration 54
# Current loss value: 1573528000.0
# Image saved as /content/output3/output_at_iteration_54.png
# Iteration 54 completed in 4s
# Start of iteration 55
# Current loss value: 1570637800.0
# Image saved as /content/output3/output_at_iteration_55.png
# Iteration 55 completed in 4s
# Start of iteration 56
# Current loss value: 1567911600.0
# Image saved as /content/output3/output_at_iteration_56.png
# Iteration 56 completed in 4s
# Start of iteration 57
# Current loss value: 1565310100.0
# Image saved as /content/output3/output_at_iteration_57.png
# Iteration 57 completed in 4s
# Start of iteration 58
# Current loss value: 1562839800.0
# Image saved as /content/output3/output_at_iteration_58.png
# Iteration 58 completed in 4s
# Start of iteration 59
# Current loss value: 1560391800.0
# Image saved as /content/output3/output_at_iteration_59.png
# Iteration 59 completed in 4s
# Start of iteration 60
# Current loss value: 1558144500.0
# Image saved as /content/output3/output_at_iteration_60.png
# Iteration 60 completed in 4s
# Start of iteration 61
# Current loss value: 1555869600.0
# Image saved as /content/output3/output_at_iteration_61.png
# Iteration 61 completed in 4s
# Start of iteration 62
# Current loss value: 1553746400.0
# Image saved as /content/output3/output_at_iteration_62.png
# Iteration 62 completed in 4s
# Start of iteration 63
# Current loss value: 1551547600.0
# Image saved as /content/output3/output_at_iteration_63.png
# Iteration 63 completed in 4s
# Start of iteration 64
# Current loss value: 1549416800.0
# Image saved as /content/output3/output_at_iteration_64.png
# Iteration 64 completed in 4s
# Start of iteration 65
# Current loss value: 1547360300.0
# Image saved as /content/output3/output_at_iteration_65.png
# Iteration 65 completed in 4s
# Start of iteration 66
# Current loss value: 1545464700.0
# Image saved as /content/output3/output_at_iteration_66.png
# Iteration 66 completed in 4s
# Start of iteration 67
# Current loss value: 1543562000.0
# Image saved as /content/output3/output_at_iteration_67.png
# Iteration 67 completed in 4s
# Start of iteration 68
# Current loss value: 1541780900.0
# Image saved as /content/output3/output_at_iteration_68.png
# Iteration 68 completed in 4s
# Start of iteration 69
# Current loss value: 1540050700.0
# Image saved as /content/output3/output_at_iteration_69.png
# Iteration 69 completed in 4s
# Start of iteration 70
# Current loss value: 1538360600.0
# Image saved as /content/output3/output_at_iteration_70.png
# Iteration 70 completed in 4s
# Start of iteration 71
# Current loss value: 1536730500.0
# Image saved as /content/output3/output_at_iteration_71.png
# Iteration 71 completed in 4s
# Start of iteration 72
# Current loss value: 1535158700.0
# Image saved as /content/output3/output_at_iteration_72.png
# Iteration 72 completed in 4s
# Start of iteration 73
# Current loss value: 1533592300.0
# Image saved as /content/output3/output_at_iteration_73.png
# Iteration 73 completed in 4s
# Start of iteration 74
# Current loss value: 1532117600.0
# Image saved as /content/output3/output_at_iteration_74.png
# Iteration 74 completed in 4s
# Start of iteration 75
# Current loss value: 1530665500.0
# Image saved as /content/output3/output_at_iteration_75.png
# Iteration 75 completed in 4s
# Start of iteration 76
# Current loss value: 1529290600.0
# Image saved as /content/output3/output_at_iteration_76.png
# Iteration 76 completed in 4s
# Start of iteration 77
# Current loss value: 1527922600.0
# Image saved as /content/output3/output_at_iteration_77.png
# Iteration 77 completed in 4s
# Start of iteration 78
# Current loss value: 1526643800.0
# Image saved as /content/output3/output_at_iteration_78.png
# Iteration 78 completed in 4s
# Start of iteration 79
# Current loss value: 1525373700.0
# Image saved as /content/output3/output_at_iteration_79.png
# Iteration 79 completed in 4s
# Start of iteration 80
# Current loss value: 1524139800.0
# Image saved as /content/output3/output_at_iteration_80.png
# Iteration 80 completed in 4s
# Start of iteration 81
# Current loss value: 1522908300.0
# Image saved as /content/output3/output_at_iteration_81.png
# Iteration 81 completed in 4s
# Start of iteration 82
# Current loss value: 1521740000.0
# Image saved as /content/output3/output_at_iteration_82.png
# Iteration 82 completed in 4s
# Start of iteration 83
# Current loss value: 1520524500.0
# Image saved as /content/output3/output_at_iteration_83.png
# Iteration 83 completed in 4s
# Start of iteration 84
# Current loss value: 1519413100.0
# Image saved as /content/output3/output_at_iteration_84.png
# Iteration 84 completed in 4s
# Start of iteration 85
# Current loss value: 1518241400.0
# Image saved as /content/output3/output_at_iteration_85.png
# Iteration 85 completed in 4s
# Start of iteration 86
# Current loss value: 1517179400.0
# Image saved as /content/output3/output_at_iteration_86.png
# Iteration 86 completed in 4s
# Start of iteration 87
# Current loss value: 1516078700.0
# Image saved as /content/output3/output_at_iteration_87.png
# Iteration 87 completed in 4s
# Start of iteration 88
# Current loss value: 1515047200.0
# Image saved as /content/output3/output_at_iteration_88.png
# Iteration 88 completed in 4s
# Start of iteration 89
# Current loss value: 1513994200.0
# Image saved as /content/output3/output_at_iteration_89.png
# Iteration 89 completed in 4s
# Start of iteration 90
# Current loss value: 1512979500.0
# Image saved as /content/output3/output_at_iteration_90.png
# Iteration 90 completed in 4s
# Start of iteration 91
# Current loss value: 1511965000.0
# Image saved as /content/output3/output_at_iteration_91.png
# Iteration 91 completed in 4s
# Start of iteration 92
# Current loss value: 1510999700.0
# Image saved as /content/output3/output_at_iteration_92.png
# Iteration 92 completed in 4s
# Start of iteration 93
# Current loss value: 1510031500.0
# Image saved as /content/output3/output_at_iteration_93.png
# Iteration 93 completed in 4s
# Start of iteration 94
# Current loss value: 1509106300.0
# Image saved as /content/output3/output_at_iteration_94.png
# Iteration 94 completed in 4s
# Start of iteration 95
# Current loss value: 1508180600.0
# Image saved as /content/output3/output_at_iteration_95.png
# Iteration 95 completed in 4s
# Start of iteration 96
# Current loss value: 1507273500.0
# Image saved as /content/output3/output_at_iteration_96.png
# Iteration 96 completed in 4s
# Start of iteration 97
# Current loss value: 1506352500.0
# Image saved as /content/output3/output_at_iteration_97.png
# Iteration 97 completed in 4s
# Start of iteration 98
# Current loss value: 1505494500.0
# Image saved as /content/output3/output_at_iteration_98.png
# Iteration 98 completed in 4s
# Start of iteration 99
# Current loss value: 1504678800.0
# Image saved as /content/output3/output_at_iteration_99.png
# Iteration 99 completed in 4s

# %% [markdown]
# # 8) Generar imágenes para distintas combinaciones de pesos de las losses. Explicar las diferencias. (Adjuntar las imágenes generadas como archivos separados.)
#
# Respuesta: La loss contiene dos términos, uno correspondiente al estilo y el otro al contenido. Lo que permite regular el énfasis en reconstruir el estilo o bien el contenido de la imagen.Las imágenes generadas originalmente hacían mayor énfasis en el estilo, nosotros generamos la inversa, haciendo mayor énfasis en el contenido. Se adjuntan las imágenes.
#
# # 9) Cambiar las imágenes de contenido y estilo por unas elegidas por usted. Adjuntar el resultado.
#
# Respuesta: Se adjuntan dos combinaciones diferentes, debajo la modificación del código para cargar las imágenes y cambiar el directorio de salida

# %% [markdown]
# 8) Se generan imágenes con peso 1 para estilo y 10 para contenido. Las imágenes de salida se generan en el directorio output2

# %%
total_variation_weight=0.1
style_weight=1
content_weight=10

# !mkdir /content/output2
result_prefix = Path("/content/output2")

# %%
#!mkdir /content/output3

base_image_path = Path("/content/foto.jpg")
style_reference_image_path = Path("/content/art.jpg")
result_prefix = Path("/content/output3")
iterations = 100

# %%
#!mkdir /content/output4
total_variation_weight=0.1
style_weight=7
content_weight=2

base_image_path = Path("/content/foto1.jpg")
style_reference_image_path = Path("/content/art1.jpg")
result_prefix = Path("/content/output4")
iterations = 100
